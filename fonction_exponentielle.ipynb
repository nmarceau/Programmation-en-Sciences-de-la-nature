# %% [markdown]
# # Fonction exponentielle

# %%
import numpy as np
import matplotlib.pyplot as plt

x = [-3, -2, -1, 0, 1, 2]
y = [-50/27, -14/9, -2/3, 2, 10, 34]

plt.plot(x, y, color='blue', marker='o', markersize=10)
plt.show()
