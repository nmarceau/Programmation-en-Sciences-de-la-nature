# %% [markdown]
# ### La racine carrée

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100) 
y = np.sqrt(x) 

plt.plot(x, y, label='y = √x')  
plt.xlabel('x')  
plt.ylabel('√x') 
plt.title('Graphique de la racine carrée de x') 
plt.legend()  
plt.grid(True)  
plt.show()

# %% [markdown]
# ### La valeur absolue

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)

plt.plot(x, abs(x) - 2)
plt.axhline(y = 0, color = 'black', linestyle='--') 
plt.axvline(x = 0, color = 'black', linestyle='--') 

plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# ### La partie entière inférieure - plancher

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 1000) 
y = np.floor(x) 

plt.plot(x, y, label='y = |x|')  
plt.xlabel('x')  
plt.ylabel('|x|') 
plt.title('Graphique de la partie entière inférieure de x') 
plt.legend()  
plt.grid(True)  
plt.show()

# %% [markdown]
# ### La partie entière supérieure - plafond

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 1000) 
y = np.ceil(x) 

plt.plot(x, y, label='y = |x|')  
plt.xlabel('x')  
plt.ylabel('|x|') 
plt.title('Graphique de la partie entière supérieure de x') 
plt.legend()  
plt.grid(True)  
plt.show()
